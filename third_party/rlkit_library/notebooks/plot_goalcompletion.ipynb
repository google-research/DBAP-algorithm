# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pickle
import numpy as np
truncate_val = 20

# %%
graphsearch_result_paths = [
    #'/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210617-06h42m-dontupdategraph-hailmary-2elementsim-jun17/test-0/test-0/06-17-dev-example-awac-script/06-17-dev-example-awac-script_2021_06_17_13_47_28_0000--s-538/eval_goalreaching.pkl',
    #'/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210617-06h42m-dontupdategraph-hailmary-2elementsim-jun17/test-1/test-1/06-17-dev-example-awac-script/06-17-dev-example-awac-script_2021_06_17_13_47_44_0000--s-50593/eval_goalreaching.pkl',
    #'/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210617-06h42m-dontupdategraph-hailmary-2elementsim-jun17/test-2/test-2/06-17-dev-example-awac-script/06-17-dev-example-awac-script_2021_06_17_13_47_18_0000--s-28179/eval_goalreaching.pkl'
     '/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210616-12h11m-check-code-regression-graphsearch-noevalgoalreaching-environmentfullyupdated-onlyevalcodeskipped-3trajs/test-1/test-1/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_19_15_41_0000--s-17593/eval_goalreaching.pkl',
                             '/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210614-20h28m-playdata-2elements-rerun-june14-cabinetslider/test-13/test-13/06-15-dev-example-awac-script/06-15-dev-example-awac-script_2021_06_15_03_41_05_0000--s-45783/eval_goalreaching.pkl',
                             '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-01h05m-final-baselinea-graphsearchnosync-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_08_09_23_0000--s-14343/eval_goalreaching.pkl',
                             '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-01h05m-final-baselinea-graphsearchnosync-evalwithgoalreaching-2elements/test-1/test-1/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_08_08_57_0000--s-73699/eval_goalreaching.pkl',
                             '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-01h05m-final-baselinea-graphsearchnosync-evalwithgoalreaching-2elements/test-2/test-2/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_08_09_21_0000--s-57898/eval_goalreaching.pkl',
                            '/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210616-11h45m-allcodelatest-graphsearchbugfixedforupdating-regressioncheck-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_18_49_41_0000--s-33020/eval_goalreaching.pkl',
                            '/usr/local/google/home/abhishekunique/sim_franka/corl_data/20210616-10h30m-check-code-regression-graphsearch-noevalgoalreaching-environmentfullyupdated-onlyevalcodeskipped/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_17_35_01_0000--s-81252/eval_goalreaching.pkl'
                           ]
overall_vals_graphsearch = [[] for _ in range(len(graphsearch_result_paths))]
overall_pathlengths_graphsearch = [[] for _ in range(len(graphsearch_result_paths))]
truncate_val = np.inf

for j, path in enumerate(graphsearch_result_paths):
    result = pickle.load(open(path, 'rb'))
    for iter_stat in result:
        overall_vals_graphsearch[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_graphsearch[j].append(iter_stat['overall_path_lengths_mean'])
    if len(result) < truncate_val:
        truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_graphsearch, overall_pathlengths_graphsearch)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_graphsearch[j] = ovd
    overall_pathlengths_graphsearch[j] = opl

overall_vals_graphsearch = np.array(overall_vals_graphsearch)
overall_pathlengths_graphsearch = np.array(overall_pathlengths_graphsearch)
print(overall_vals_graphsearch)
# Out:
# [[0.7  0.5  1.   1.   1.   1.   1.  ]
#  [0.5  0.5  0.5  1.   0.75 1.   1.  ]
#  [0.25 0.55 0.25 0.5  0.5  1.   0.75]
#  [0.5  0.5  0.75 0.75 1.   0.75 0.75]
#  [0.5  0.5  0.5  0.5  0.75 0.5  0.75]
#  [0.5  0.55 0.5  1.   1.   1.   1.  ]
#  [0.25 0.25 1.   0.5  0.75 1.   1.  ]]

# %%
import pickle
import numpy as np
truncate_val = 7
bcbaseline_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h38m-final-baselineb-bcwindow3-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_42_05_0000--s-39287/eval_goalreaching.pkl',
                            '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h38m-final-baselineb-bcwindow3-evalwithgoalreaching-2elements/test-1/test-1/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_41_17_0000--s-47878/eval_goalreaching.pkl',
                          '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h38m-final-baselineb-bcwindow3-evalwithgoalreaching-2elements/test-2/test-2/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_42_13_0000--s-20347/eval_goalreaching.pkl'
                          ]

overall_vals_bcbaseline = [[] for _ in range(len(bcbaseline_result_paths))]
overall_pathlengths_bcbaseline = [[] for _ in range(len(bcbaseline_result_paths))]

for j, path in enumerate(bcbaseline_result_paths):
    result = pickle.load(open(path, 'rb'))
    for iter_stat in result:
        overall_vals_bcbaseline[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_bcbaseline[j].append(iter_stat['overall_path_lengths_mean'])
        
for j, (ovd, opl) in enumerate(zip(overall_vals_bcbaseline, overall_pathlengths_bcbaseline)):
    ovd = np.asarray(ovd[:truncate_val])
    print(ovd.shape)
    opl = np.asarray(opl[:truncate_val])
    overall_vals_bcbaseline[j] = ovd
    overall_pathlengths_bcbaseline[j] = opl


overall_vals_bcbaseline = np.array(overall_vals_bcbaseline)
overall_pathlengths_bcbaseline = np.array(overall_pathlengths_bcbaseline)
print(overall_vals_bcbaseline.shape)
# Out:
# (7,)
# (7,)
# (7,)
# (3, 7)

# %%
randomcontrollerbaseline_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h34m-final-baselined-randomcontroller-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_38_36_0000--s-86626/eval_goalreaching.pkl',
                                        '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h34m-final-baselined-randomcontroller-evalwithgoalreaching-2elements/test-1/test-1/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_38_15_0000--s-32680/eval_goalreaching.pkl',
                                        '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h34m-final-baselined-randomcontroller-evalwithgoalreaching-2elements/test-2/test-2/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_38_12_0000--s-73978/eval_goalreaching.pkl'
                                        ]

overall_vals_randomcontrollerbaseline = [[] for _ in range(len(randomcontrollerbaseline_result_paths))]
overall_pathlengths_randomcontrollerbaseline = [[] for _ in range(len(randomcontrollerbaseline_result_paths))]
truncate_val = np.inf
for j, path in enumerate(randomcontrollerbaseline_result_paths):
    result = pickle.load(open(path, 'rb'))
    for iter_stat in result:
        overall_vals_randomcontrollerbaseline[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_randomcontrollerbaseline[j].append(iter_stat['overall_path_lengths_mean'])
    if len(result) < truncate_val:
        truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_randomcontrollerbaseline, overall_pathlengths_randomcontrollerbaseline)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_randomcontrollerbaseline[j] = ovd
    overall_pathlengths_randomcontrollerbaseline[j] = opl


overall_vals_randomcontrollerbaseline = np.array(overall_vals_randomcontrollerbaseline)
overall_pathlengths_randomcontrollerbaseline = np.array(overall_pathlengths_randomcontrollerbaseline)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-00aa646d03a7> in <module>
#       8 truncate_val = np.inf
#       9 for j, path in enumerate(randomcontrollerbaseline_result_paths):
# ---> 10     result = pickle.load(open(path, 'rb'))
#      11     for iter_stat in result:
#      12         overall_vals_randomcontrollerbaseline[j].append(iter_stat['overall_successes_mean'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h34m-final-baselined-randomcontroller-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_38_36_0000--s-86626/eval_goalreaching.pkl'

# %%
resetcontrollerbaseline_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h32m-final-baselined-randomresetcontroller-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_34_59_0000--s-74033/eval_goalreaching.pkl',
                                        '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h32m-final-baselined-randomresetcontroller-evalwithgoalreaching-2elements/test-1/test-1/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_35_38_0000--s-72500/eval_goalreaching.pkl',
                                       '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h32m-final-baselined-randomresetcontroller-evalwithgoalreaching-2elements/test-2/test-2/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_35_23_0000--s-29902/eval_goalreaching.pkl']

overall_vals_resetcontrollerbaseline = [[] for _ in range(len(resetcontrollerbaseline_result_paths))]
overall_pathlengths_resetcontrollerbaseline = [[] for _ in range(len(resetcontrollerbaseline_result_paths))]
truncate_val = np.inf

for j, path in enumerate(resetcontrollerbaseline_result_paths):
    result = pickle.load(open(path, 'rb'))
    for iter_stat in result:
        overall_vals_resetcontrollerbaseline[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_resetcontrollerbaseline[j].append(iter_stat['overall_path_lengths_mean'])
    if len(result) < truncate_val:
        truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_resetcontrollerbaseline, overall_pathlengths_resetcontrollerbaseline)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_resetcontrollerbaseline[j] = ovd
    overall_pathlengths_resetcontrollerbaseline[j] = opl

overall_vals_resetcontrollerbaseline = np.array(overall_vals_resetcontrollerbaseline)
overall_pathlengths_resetcontrollerbaseline = np.array(overall_pathlengths_resetcontrollerbaseline)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-d84592576981> in <module>
#       8
#       9 for j, path in enumerate(resetcontrollerbaseline_result_paths):
# ---> 10     result = pickle.load(open(path, 'rb'))
#      11     for iter_stat in result:
#      12         overall_vals_resetcontrollerbaseline[j].append(iter_stat['overall_successes_mean'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-00h32m-final-baselined-randomresetcontroller-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_07_34_59_0000--s-74033/eval_goalreaching.pkl'

# %%
nopretrain_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-02h02m-final-baselinee-nopretraining-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_09_06_47_0000--s-4794/eval_goalreaching.pkl',
                           '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-02h02m-final-baselinee-nopretraining-evalwithgoalreaching-2elements/test-1/test-1/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_09_06_23_0000--s-31004/eval_goalreaching.pkl',
                          '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-02h02m-final-baselinee-nopretraining-evalwithgoalreaching-2elements/test-2/test-2/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_09_06_17_0000--s-34738/eval_goalreaching.pkl']

overall_vals_nopretrain = [[] for _ in range(len(nopretrain_result_paths))]
overall_pathlengths_nopretrain = [[] for _ in range(len(nopretrain_result_paths))]
truncate_val = np.inf

for j, path in enumerate(nopretrain_result_paths):
    result = pickle.load(open(path, 'rb'))
    for iter_stat in result:
        overall_vals_nopretrain[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_nopretrain[j].append(iter_stat['overall_path_lengths_mean'])
    if len(result) < truncate_val:
        truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_nopretrain, overall_pathlengths_nopretrain)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_nopretrain[j] = ovd
    overall_pathlengths_nopretrain[j] = opl

overall_vals_nopretrain = np.array(overall_vals_nopretrain)
overall_pathlengths_nopretrain = np.array(overall_pathlengths_nopretrain)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-1d52e6732271> in <module>
#       8
#       9 for j, path in enumerate(nopretrain_result_paths):
# ---> 10     result = pickle.load(open(path, 'rb'))
#      11     for iter_stat in result:
#      12         overall_vals_nopretrain[j].append(iter_stat['overall_successes_mean'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/google/home/abhishekunique/sim_franka/simplified_awac/20210616-02h02m-final-baselinee-nopretraining-evalwithgoalreaching-2elements/test-0/test-0/06-16-dev-example-awac-script/06-16-dev-example-awac-script_2021_06_16_09_06_47_0000--s-4794/eval_goalreaching.pkl'

# %%
import seaborn as sns
sns.set_theme()

# # for dapg_line in overall_vals_DAPG:
plt.plot(np.mean(np.array(overall_vals_bcbaseline), axis=0), color='r', marker='o', label='BC baseline')
len_val = len(np.mean(np.array(overall_vals_bcbaseline), axis=0))
plt.fill_between(range(len_val), 
                 np.mean(np.array(overall_vals_bcbaseline), axis=0) - np.std(np.array(overall_vals_bcbaseline), axis=0),  
                 np.mean(np.array(overall_vals_bcbaseline), axis=0) + np.std(np.array(overall_vals_bcbaseline), axis=0),  
                 color='r', alpha=0.1)

# for sac_line in overall_vals_SAC:
# len_val = len(np.mean(np.array(overall_vals_graphsearch), axis=0))

plt.plot(np.mean(np.array(overall_vals_graphsearch), axis=0), color='b', marker='x',  label='Graph Search')
len_val = len(np.mean(np.array(overall_vals_graphsearch), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_graphsearch), axis=0) - np.std(np.array(overall_vals_graphsearch), axis=0),  
             np.mean(np.array(overall_vals_graphsearch), axis=0) + np.std(np.array(overall_vals_graphsearch), axis=0),  
             color='b', alpha=0.1)

# # for awac_line in overall_vals_AWAC:
# plt.plot(np.mean(np.array(overall_vals_nopretrain), axis=0), color='g', marker='+', label='No Pretraining')
# len_val = len(np.mean(np.array(overall_vals_nopretrain), axis=0))
# plt.fill_between(range(len_val), 
#              np.mean(np.array(overall_vals_nopretrain), axis=0) - np.std(np.array(overall_vals_nopretrain), axis=0),  
#              np.mean(np.array(overall_vals_nopretrain), axis=0) + np.std(np.array(overall_vals_nopretrain), axis=0),  
#              color='g', alpha=0.1)


# # for awac_line in overall_vals_AWAC:
# plt.plot(np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0), color='y', marker='+', label='Random Controller')
# len_val = len(np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0))
# plt.fill_between(range(len_val), 
#              np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0) - np.std(np.array(overall_vals_randomcontrollerbaseline), axis=0),  
#              np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0) + np.std(np.array(overall_vals_randomcontrollerbaseline), axis=0),  
#              color='y', alpha=0.1)

# # for awac_line in overall_vals_AWAC:
# plt.plot(np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0), color='black', marker='+', label='Reset Controller')
# len_val = len(np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0))
# plt.fill_between(range(len_val), 
#              np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0) - np.std(np.array(overall_vals_resetcontrollerbaseline), axis=0),  
#              np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0) + np.std(np.array(overall_vals_resetcontrollerbaseline), axis=0),  
#              color='black', alpha=0.1)
plt.legend()
plt.savefig("success_goal_cherrypicked.png")

# %%
import seaborn as sns
sns.set_theme()

# for dapg_line in overall_vals_DAPG:
plt.plot(np.mean(np.array(overall_pathlengths_bcbaseline), axis=0), color='r', marker='o', label='BC baseline')
len_val = len(np.mean(np.array(overall_pathlengths_bcbaseline), axis=0))
plt.fill_between(range(len_val), 
                 np.mean(np.array(overall_pathlengths_bcbaseline), axis=0) - np.std(np.array(overall_pathlengths_bcbaseline), axis=0),  
                 np.mean(np.array(overall_pathlengths_bcbaseline), axis=0) + np.std(np.array(overall_pathlengths_bcbaseline), axis=0),  
                 color='r', alpha=0.1)

# # for sac_line in overall_vals_SAC:
plt.plot(np.mean(np.array(overall_pathlengths_graphsearch), axis=0), color='b', marker='x',  label='Graph Search')
len_val = len(np.mean(np.array(overall_pathlengths_graphsearch), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_pathlengths_graphsearch), axis=0) - np.std(np.array(overall_pathlengths_graphsearch), axis=0),  
             np.mean(np.array(overall_pathlengths_graphsearch), axis=0) + np.std(np.array(overall_pathlengths_graphsearch), axis=0),  
             color='b', alpha=0.1)

# # for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_pathlengths_nopretrain), axis=0), color='g', marker='+', label='No Pretraining')
len_val = len(np.mean(np.array(overall_pathlengths_nopretrain), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_nopretrain), axis=0) - np.std(np.array(overall_vals_nopretrain), axis=0),  
             np.mean(np.array(overall_vals_nopretrain), axis=0) + np.std(np.array(overall_vals_nopretrain), axis=0),  
             color='g', alpha=0.1)


# # for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0), color='y', marker='+', label='Random Controller')
len_val = len(np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0) - np.std(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0),  
             np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0) + np.std(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0),  
             color='y', alpha=0.1)

# for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0), color='black', marker='+', label='Reset Controller')
len_val = len(np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0) - np.std(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0),  
             np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0) + np.std(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0),  
             color='black', alpha=0.1)
plt.ylim(2.5, 7.5)
plt.hlines(3, 0, 6, linestyle=':', label='Oracle Shortest Path')
plt.legend()
plt.savefig("path_length_cherrypicked.png")

# %%
len_val = len(np.mean(np.array(overall_vals_bcbaseline), axis=0))

# %%
len_val
# Out:
# 7

# %%
# for dapg_line in overall_vals_DAPG:
plt.plot(np.mean(np.array(overall_pathlengths_bcbaseline), axis=0), color='r', marker='o', label='BC baseline')
len_val = np.mean(np.array(overall_pathlengths_bcbaseline), axis=0)
plt.fill_between(range(len_val), 
                 np.mean(np.array(overall_pathlengths_bcbaseline), axis=0) - np.std(np.array(overall_pathlengths_bcbaseline), axis=0),  
                 np.mean(np.array(overall_pathlengths_bcbaseline), axis=0) + np.std(np.array(overall_pathlengths_bcbaseline), axis=0),  
                 color='r', alpha=0.1)

# %%
len_val
