# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import pickle
import numpy as np
import torch
truncate_val = 26

# %%
graphsearch_result_paths = [
    '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210618-07h54m-ours-finaleval-june17-graphsearchnoupdate-clouddump-seed0-dumpfixed-longerrun/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_15_00_41_0000--s-50506/itr_0.pkl',
    '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210618-08h00m-ours-finaleval-june17-graphsearchnoupdate-clouddump-seed1-dumpfixed-longerrun/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_15_05_57_0000--s-87214/itr_0.pkl',
    '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210618-08h02m-ours-finaleval-june17-graphsearchnoupdate-clouddump-seed2-dumpfixed-longerrun/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_15_08_13_0000--s-98325/itr_0.pkl',
#     '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210618-00h01m-ours-finaleval-june17-graphsearchnoupdate-clouddump-seed0-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_07_07_00_0000--s-52766/itr_0.pkl',
#     '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210618-00h04m-ours-finaleval-june17-graphsearchnoupdate-clouddump-seed1-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_07_09_43_0000--s-94436/itr_0.pkl',                       
#     '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210618-00h06m-ours-finaleval-june17-graphsearchnoupdate-clouddump-seed2-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_07_13_01_0000--s-59728/itr_0.pkl'
]
overall_vals_graphsearch = [[] for _ in range(len(graphsearch_result_paths))]
overall_pathlengths_graphsearch = [[] for _ in range(len(graphsearch_result_paths))]
# truncate_val = np.inf

for j, path in enumerate(graphsearch_result_paths):
    result = torch.load(open(path, 'rb'))['paths']
    for iter_stat in result:
        overall_vals_graphsearch[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_graphsearch[j].append(iter_stat['overall_path_lengths_mean'])
#     if len(result) < truncate_val:
#         truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_graphsearch, overall_pathlengths_graphsearch)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_graphsearch[j] = ovd
    overall_pathlengths_graphsearch[j] = opl

overall_vals_graphsearch = np.array(overall_vals_graphsearch)
overall_pathlengths_graphsearch = np.array(overall_pathlengths_graphsearch) - 1

# %%
import pickle
import numpy as np
# truncate_val = 7
bcbaseline_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h22m-baselineb-finaleval-june17-bc-clouddump-seed0-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_26_57_0000--s-61090/itr_0.pkl',
                            '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h20m-baselineb-finaleval-june17-bc-clouddump-seed1-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_25_16_0000--s-19004/itr_0.pkl',
                          '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h18m-baselineb-finaleval-june17-bc-clouddump-seed2-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_23_22_0000--s-87800/itr_0.pkl'
                          ]

overall_vals_bcbaseline = [[] for _ in range(len(bcbaseline_result_paths))]
overall_pathlengths_bcbaseline = [[] for _ in range(len(bcbaseline_result_paths))]
# truncate_val = np.inf

for j, path in enumerate(bcbaseline_result_paths):
    result = torch.load(open(path, 'rb'))['paths']
    for iter_stat in result:
        overall_vals_bcbaseline[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_bcbaseline[j].append(iter_stat['overall_path_lengths_mean'])
#     if len(result) < truncate_val:
#         truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_bcbaseline, overall_pathlengths_bcbaseline)):
    ovd = np.asarray(ovd[:truncate_val])
    print(ovd.shape)
    opl = np.asarray(opl[:truncate_val])
    overall_vals_bcbaseline[j] = ovd
    overall_pathlengths_bcbaseline[j] = opl


overall_vals_bcbaseline = np.array(overall_vals_bcbaseline)
overall_pathlengths_bcbaseline = np.array(overall_pathlengths_bcbaseline) - 1
print(overall_vals_bcbaseline.shape)
# Out:
# (26,)
# (26,)
# (26,)
# (3, 26)

# %%
randomcontrollerbaseline_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h38m-baselinec-finaleval-june17-randomcontroller-clouddump-seed0-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_43_26_0000--s-35762/itr_0.pkl',
                                        '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h40m-baselinec-finaleval-june17-randomcontroller-clouddump-seed1-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_46_17_0000--s-64018/itr_0.pkl',
                                        '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h43m-baselinec-finaleval-june17-randomcontroller-clouddump-seed2-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_48_12_0000--s-11293/itr_0.pkl'
                                        ]

overall_vals_randomcontrollerbaseline = [[] for _ in range(len(randomcontrollerbaseline_result_paths))]
overall_pathlengths_randomcontrollerbaseline = [[] for _ in range(len(randomcontrollerbaseline_result_paths))]
# truncate_val = np.inf
for j, path in enumerate(randomcontrollerbaseline_result_paths):
    result = torch.load(open(path, 'rb'))['paths']
    for iter_stat in result:
        overall_vals_randomcontrollerbaseline[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_randomcontrollerbaseline[j].append(iter_stat['overall_path_lengths_mean'])
#     if len(result) < truncate_val:
#         truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_randomcontrollerbaseline, overall_pathlengths_randomcontrollerbaseline)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_randomcontrollerbaseline[j] = ovd
    overall_pathlengths_randomcontrollerbaseline[j] = opl


overall_vals_randomcontrollerbaseline = np.array(overall_vals_randomcontrollerbaseline)
overall_pathlengths_randomcontrollerbaseline = np.array(overall_pathlengths_randomcontrollerbaseline) - 1

# %%
resetcontrollerbaseline_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h50m-baselined-finaleval-june17-randomresetcontroller-clouddump-seed0-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_55_47_0000--s-27809/itr_0.pkl',
                                        '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h52m-baselined-finaleval-june17-randomresetcontroller-clouddump-seed1-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_58_10_0000--s-39839/itr_0.pkl',
                                       '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h55m-baselined-finaleval-june17-randomresetcontroller-clouddump-seed2-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_07_00_18_0000--s-98198/itr_0.pkl']

overall_vals_resetcontrollerbaseline = [[] for _ in range(len(resetcontrollerbaseline_result_paths))]
overall_pathlengths_resetcontrollerbaseline = [[] for _ in range(len(resetcontrollerbaseline_result_paths))]
# truncate_val = np.inf

for j, path in enumerate(resetcontrollerbaseline_result_paths):
    result = torch.load(open(path, 'rb'))['paths']
    for iter_stat in result:
        overall_vals_resetcontrollerbaseline[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_resetcontrollerbaseline[j].append(iter_stat['overall_path_lengths_mean'])
#     if len(result) < truncate_val:
#         truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_resetcontrollerbaseline, overall_pathlengths_resetcontrollerbaseline)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_resetcontrollerbaseline[j] = ovd
    overall_pathlengths_resetcontrollerbaseline[j] = opl

overall_vals_resetcontrollerbaseline = np.array(overall_vals_resetcontrollerbaseline)
overall_pathlengths_resetcontrollerbaseline = np.array(overall_pathlengths_resetcontrollerbaseline) - 1

# %%
nopretrain_result_paths = ['/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h27m-baselinee-finaleval-june17-nopretrain-clouddump-seed0-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_33_05_0000--s-19559/itr_0.pkl',
                            '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h31m-baselinee-finaleval-june17-nopretrain-clouddump-seed1-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_35_41_0000--s-62728/itr_0.pkl',
                            '/usr/local/google/home/abhishekunique/sim_franka/eval_plot_data/20210617-23h33m-baselinee-finaleval-june17-nopretrain-clouddump-seed2-dumpfixed/test-0/test-0/06-18-dev-example-awac-script/06-18-dev-example-awac-script_2021_06_18_06_38_00_0000--s-95449/itr_0.pkl']

overall_vals_nopretrain = [[] for _ in range(len(nopretrain_result_paths))]
overall_pathlengths_nopretrain = [[] for _ in range(len(nopretrain_result_paths))]
# truncate_val = np.inf

for j, path in enumerate(nopretrain_result_paths):
    result = torch.load(open(path, 'rb'))['paths']
    for iter_stat in result:
        overall_vals_nopretrain[j].append(iter_stat['overall_successes_mean'])
        overall_pathlengths_nopretrain[j].append(iter_stat['overall_path_lengths_mean'])
#     if len(result) < truncate_val:
#         truncate_val = len(result)
for j, (ovd, opl) in enumerate(zip(overall_vals_nopretrain, overall_pathlengths_nopretrain)):
    ovd = np.asarray(ovd[:truncate_val])
    opl = np.asarray(opl[:truncate_val])
    overall_vals_nopretrain[j] = ovd
    overall_pathlengths_nopretrain[j] = opl

overall_vals_nopretrain = np.array(overall_vals_nopretrain)
overall_pathlengths_nopretrain = np.array(overall_pathlengths_nopretrain) - 1

# %%
import seaborn as sns
sns.set_theme()

# for dapg_line in overall_vals_DAPG:
plt.plot(np.mean(np.array(overall_vals_bcbaseline), axis=0), color='r', marker='o', label='Pre-trained low-level, BC high level')
len_val = len(np.mean(np.array(overall_vals_bcbaseline), axis=0))
plt.fill_between(range(len_val), 
                 np.mean(np.array(overall_vals_bcbaseline), axis=0) - np.std(np.array(overall_vals_bcbaseline), axis=0),  
                 np.mean(np.array(overall_vals_bcbaseline), axis=0) + np.std(np.array(overall_vals_bcbaseline), axis=0),  
                 color='r', alpha=0.1)

plt.plot(np.mean(np.array(overall_vals_graphsearch), axis=0), color='b', marker='x',  label='DBAP (Ours)')
len_val = len(np.mean(np.array(overall_vals_graphsearch), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_graphsearch), axis=0) - np.std(np.array(overall_vals_graphsearch), axis=0),  
             np.mean(np.array(overall_vals_graphsearch), axis=0) + np.std(np.array(overall_vals_graphsearch), axis=0),  
             color='b', alpha=0.1)

# # for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_vals_nopretrain), axis=0), color='g', marker='+', label='No Pretraining (Gupta et al.)')
len_val = len(np.mean(np.array(overall_vals_nopretrain), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_nopretrain), axis=0) - np.std(np.array(overall_vals_nopretrain), axis=0),  
             np.mean(np.array(overall_vals_nopretrain), axis=0) + np.std(np.array(overall_vals_nopretrain), axis=0),  
             color='g', alpha=0.1)


# for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0), color='y', marker='+', label='Random High Level Controller')
len_val = len(np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0) - np.std(np.array(overall_vals_randomcontrollerbaseline), axis=0),  
             np.mean(np.array(overall_vals_randomcontrollerbaseline), axis=0) + np.std(np.array(overall_vals_randomcontrollerbaseline), axis=0),  
             color='y', alpha=0.1)

# for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0), color='black', marker='+', label='Reset Controller (Eysenbach et al.)')
len_val = len(np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0) - np.std(np.array(overall_vals_resetcontrollerbaseline), axis=0),  
             np.mean(np.array(overall_vals_resetcontrollerbaseline), axis=0) + np.std(np.array(overall_vals_resetcontrollerbaseline), axis=0),  
             color='black', alpha=0.1)
plt.ylabel('Success Rate')
plt.xlabel('Training Steps (x 10000)')
plt.title("Success Rate for Reaching Long Horizon Goals")
# lgd = plt.legend(bbox_to_anchor=(-0.15, 0.7), ncol=3)
plt.savefig("success_goal_CORLpaper.png", bbox_inches="tight")

# %%
import seaborn as sns
sns.set_theme()

# for dapg_line in overall_vals_DAPG:
plt.plot(np.mean(np.array(overall_pathlengths_bcbaseline), axis=0), color='r', marker='o', label='Pre-trained low-level, BC high level')
len_val = len(np.mean(np.array(overall_pathlengths_bcbaseline), axis=0))
plt.fill_between(range(len_val), 
                 np.mean(np.array(overall_pathlengths_bcbaseline), axis=0) - np.std(np.array(overall_pathlengths_bcbaseline), axis=0),  
                 np.mean(np.array(overall_pathlengths_bcbaseline), axis=0) + np.std(np.array(overall_pathlengths_bcbaseline), axis=0),  
                 color='r', alpha=0.1)

# # for sac_line in overall_vals_SAC:
plt.plot(np.mean(np.array(overall_pathlengths_graphsearch), axis=0), color='b', marker='x',  label='DBAP (Ours)')
len_val = len(np.mean(np.array(overall_pathlengths_graphsearch), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_pathlengths_graphsearch), axis=0) - np.std(np.array(overall_pathlengths_graphsearch), axis=0),  
             np.mean(np.array(overall_pathlengths_graphsearch), axis=0) + np.std(np.array(overall_pathlengths_graphsearch), axis=0),  
             color='b', alpha=0.1)

# # # for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_pathlengths_nopretrain), axis=0), color='g', marker='+', label='No Pretraining (Gupta et al.)')
len_val = len(np.mean(np.array(overall_pathlengths_nopretrain), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_vals_nopretrain), axis=0) - np.std(np.array(overall_vals_nopretrain), axis=0),  
             np.mean(np.array(overall_vals_nopretrain), axis=0) + np.std(np.array(overall_vals_nopretrain), axis=0),  
             color='g', alpha=0.1)


# # for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0), color='y', marker='+', label='Random High Level Controller')
len_val = len(np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0) - np.std(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0),  
             np.mean(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0) + np.std(np.array(overall_pathlengths_randomcontrollerbaseline), axis=0),  
             color='y', alpha=0.1)

# for awac_line in overall_vals_AWAC:
plt.plot(np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0), color='black', marker='+', label='Reset Controller (Eysenbach et al.)')
len_val = len(np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0))
plt.fill_between(range(len_val), 
             np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0) - np.std(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0),  
             np.mean(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0) + np.std(np.array(overall_pathlengths_resetcontrollerbaseline), axis=0),  
             color='black', alpha=0.1)
plt.ylim(1.5, 6.5)
plt.hlines(2, 0, 26, linestyle=':', label='Oracle Shortest Path')
plt.ylabel("Number of High Level Tasks Executed")
plt.xlabel("Training Steps (x10000)")
plt.title("Path Lengths for Reaching Long Horizon Goals")
plt.savefig("path_length_CORLpaper.png",bbox_inches="tight")
